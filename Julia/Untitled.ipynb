# %%
import numpy as np
import itertools

# %%
element_combo = {}
element = ["energy","fusion","space","hydrogen","time","nebula","erosion","star","mass",
           "spacetime","gravity","neutron star","supernova","planet","meteor shower",
           "human","cave","meteor","earth","space travel","cracking station",
           "hatching station","egg","dragon rider","dust","nesting station",
           "metal dust","nested egg","baby dragon","dragon","dragonfire","mars",
           "martian sand","martian metal","thermal bricks","forge","fire cladding",
           "structure","dragon enclosure","terran housing"]
element.sort()

# %%
for combo in itertools.combinations(element,2):
    if combo not in element_combo:
        element_combo[frozenset(combo)] = ""

# %%
#Worked
element_combo[frozenset(("energy","hydrogen"))] = "Worked"
element_combo[frozenset(("energy","mass"))] = "Worked"
element_combo[frozenset(("energy","time"))] = "Worked"
element_combo[frozenset(("fusion","nebula"))] = "Worked"
element_combo[frozenset(("hydrogen","space"))] = "Worked"
element_combo[frozenset(("space","time"))] = "Worked"
element_combo[frozenset(("spacetime","mass"))] = "Worked"
element_combo[frozenset(("gravity","star"))] = "Worked"
element_combo[frozenset(("neutron star","time"))] = "Worked"
element_combo[frozenset(("supernova","mass"))] = "Worked"
element_combo[frozenset(("supernova","space"))] = "Worked"
element_combo[frozenset(("planet","energy"))] = "Worked"
element_combo[frozenset(("planet","meteor shower"))] = "Worked"
element_combo[frozenset(("planet","time"))] = "Worked"
element_combo[frozenset(("human","planet"))] = "Worked"
element_combo[frozenset(("human","spacetime"))] = "Worked"
element_combo[frozenset(("cave","energy"))] = "Worked"
element_combo[frozenset(("cave","time"))] = "Worked"
element_combo[frozenset(("cracking station","meteor"))] = "Worked"
element_combo[frozenset(("human","space travel"))] = "Worked"
element_combo[frozenset(("planet","meteor"))] = "Worked"
element_combo[frozenset(("cave","dust"))] = "Worked"
element_combo[frozenset(("meteor","dust"))] = "Worked"
element_combo[frozenset(("egg","nesting station"))] = "Worked"
element_combo[frozenset(("hatching station","nested egg"))] = "Worked"
element_combo[frozenset(("baby dragon","time"))] = "Worked"
element_combo[frozenset(("dragon rider","dragon"))] = "Worked"
element_combo[frozenset(("planet","space travel"))] = "Worked"
element_combo[frozenset(("erosion","mars"))] = "Worked"
element_combo[frozenset(("metal dust","mars"))] = "Worked"
element_combo[frozenset(("energy","martian sand"))] = "Worked"
element_combo[frozenset(("dragonfire","thermal bricks"))] = "Worked"
element_combo[frozenset(("thermal bricks","fusion"))] = "Worked"
element_combo[frozenset(("martian metal","thermal bricks"))] = "Worked"
element_combo[frozenset(("structure","fire cladding"))] = "Worked"
element_combo[frozenset(("structure","human"))] = "Worked"

# %%
#Didnt work
element_combo[frozenset(("energy","erosion"))] = "Did Not Work"
element_combo[frozenset(("energy","fusion"))] = "Did Not Work"
element_combo[frozenset(("energy","space"))] = "Did Not Work"
element_combo[frozenset(("energy","star"))] = "Did Not Work"
element_combo[frozenset(("energy","nebula"))] = "Did Not Work"
element_combo[frozenset(("erosion","fusion"))] = "Did Not Work"
element_combo[frozenset(("erosion","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("erosion","mass"))] = "Did Not Work"
element_combo[frozenset(("erosion","nebula"))] = "Did Not Work"
element_combo[frozenset(("erosion","space"))] = "Did Not Work"
element_combo[frozenset(("erosion","star"))] = "Did Not Work"
element_combo[frozenset(("erosion","time"))] = "Did Not Work"
element_combo[frozenset(("fusion","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("fusion","mass"))] = "Did Not Work"
element_combo[frozenset(("fusion","space"))] = "Did Not Work"
element_combo[frozenset(("fusion","star"))] = "Did Not Work"
element_combo[frozenset(("fusion","time"))] = "Did Not Work"
element_combo[frozenset(("hydrogen","mass"))] = "Did Not Work"
element_combo[frozenset(("hydrogen","nebula"))] = "Did Not Work"
element_combo[frozenset(("hydrogen","star"))] = "Did Not Work"
element_combo[frozenset(("hydrogen","time"))] = "Did Not Work"
element_combo[frozenset(("mass","nebula"))] = "Did Not Work"
element_combo[frozenset(("mass","space"))] = "Did Not Work"
element_combo[frozenset(("mass","star"))] = "Did Not Work"
element_combo[frozenset(("mass","time"))] = "Did Not Work"
element_combo[frozenset(("nebula","space"))] = "Did Not Work"
element_combo[frozenset(("nebula","star"))] = "Did Not Work"
element_combo[frozenset(("nebula","time"))] = "Did Not Work"
element_combo[frozenset(("space","star"))] = "Did Not Work"
element_combo[frozenset(("star","time"))] = "Did Not Work"
element_combo[frozenset(("spacetime","energy"))] = "Did Not Work"
element_combo[frozenset(("spacetime","erosion"))] = "Did Not Work"
element_combo[frozenset(("spacetime","fusion"))] = "Did Not Work"
element_combo[frozenset(("spacetime","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("spacetime","nebula"))] = "Did Not Work"
element_combo[frozenset(("spacetime","space"))] = "Did Not Work"
element_combo[frozenset(("spacetime","star"))] = "Did Not Work"
element_combo[frozenset(("spacetime","time"))] = "Did Not Work"
element_combo[frozenset(("gravity","energy"))] = "Did Not Work"
element_combo[frozenset(("gravity","erosion"))] = "Did Not Work"
element_combo[frozenset(("gravity","fusion"))] = "Did Not Work"
element_combo[frozenset(("gravity","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("gravity","mass"))] = "Did Not Work"
element_combo[frozenset(("gravity","nebula"))] = "Did Not Work"
element_combo[frozenset(("gravity","space"))] = "Did Not Work"
element_combo[frozenset(("gravity","spacetime"))] = "Did Not Work"
element_combo[frozenset(("gravity","time"))] = "Did Not Work"
element_combo[frozenset(("neutron star","energy"))] = "Did Not Work"
element_combo[frozenset(("neutron star","erosion"))] = "Did Not Work"
element_combo[frozenset(("neutron star","fusion"))] = "Did Not Work"
element_combo[frozenset(("neutron star","gravity"))] = "Did Not Work"
element_combo[frozenset(("neutron star","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("neutron star","mass"))] = "Did Not Work"
element_combo[frozenset(("neutron star","nebula"))] = "Did Not Work"
element_combo[frozenset(("neutron star","space"))] = "Did Not Work"
element_combo[frozenset(("neutron star","spacetime"))] = "Did Not Work"
element_combo[frozenset(("neutron star","star"))] = "Did Not Work"
element_combo[frozenset(("supernova","energy"))] = "Did Not Work"
element_combo[frozenset(("supernova","erosion"))] = "Did Not Work"
element_combo[frozenset(("supernova","fusion"))] = "Did Not Work"
element_combo[frozenset(("supernova","gravity"))] = "Did Not Work"
element_combo[frozenset(("supernova","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("supernova","nebula"))] = "Did Not Work"
element_combo[frozenset(("supernova","neutron star"))] = "Did Not Work"
element_combo[frozenset(("supernova","spacetime"))] = "Did Not Work"
element_combo[frozenset(("supernova","star"))] = "Did Not Work"
element_combo[frozenset(("supernova","time"))] = "Did Not Work"
element_combo[frozenset(("planet","erosion"))] = "Did Not Work"
element_combo[frozenset(("planet","fusion"))] = "Did Not Work"
element_combo[frozenset(("planet","gravity"))] = "Did Not Work"
element_combo[frozenset(("planet","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("planet","mass"))] = "Did Not Work"
element_combo[frozenset(("planet","nebula"))] = "Did Not Work"
element_combo[frozenset(("planet","neutron star"))] = "Did Not Work"
element_combo[frozenset(("planet","space"))] = "Did Not Work"
element_combo[frozenset(("planet","spacetime"))] = "Did Not Work"
element_combo[frozenset(("planet","star"))] = "Did Not Work"
element_combo[frozenset(("planet","supernova"))] = "Did Not Work"
element_combo[frozenset(("human","cave"))] = "Did Not Work"
element_combo[frozenset(("human","energy"))] = "Did Not Work"
element_combo[frozenset(("human","erosion"))] = "Did Not Work"
element_combo[frozenset(("human","fusion"))] = "Did Not Work"
element_combo[frozenset(("human","gravity"))] = "Did Not Work"
element_combo[frozenset(("human","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("human","mass"))] = "Did Not Work"
element_combo[frozenset(("human","meteor"))] = "Did Not Work"
element_combo[frozenset(("human","meteor shower"))] = "Did Not Work"
element_combo[frozenset(("human","nebula"))] = "Did Not Work"
element_combo[frozenset(("human","neutron star"))] = "Did Not Work"
element_combo[frozenset(("human","space"))] = "Did Not Work"
element_combo[frozenset(("human","star"))] = "Did Not Work"
element_combo[frozenset(("human","supernova"))] = "Did Not Work"
element_combo[frozenset(("human","time"))] = "Did Not Work"
element_combo[frozenset(("cave","earth"))] = "Did Not Work"
element_combo[frozenset(("cave","erosion"))] = "Did Not Work"
element_combo[frozenset(("cave","fusion"))] = "Did Not Work"
element_combo[frozenset(("cave","gravity"))] = "Did Not Work"
element_combo[frozenset(("cave","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("cave","mass"))] = "Did Not Work"
element_combo[frozenset(("cave","meteor"))] = "Did Not Work"
element_combo[frozenset(("cave","meteor shower"))] = "Did Not Work"
element_combo[frozenset(("cave","nebula"))] = "Did Not Work"
element_combo[frozenset(("cave","neutron star"))] = "Did Not Work"
element_combo[frozenset(("cave","planet"))] = "Did Not Work"
element_combo[frozenset(("cave","space"))] = "Did Not Work"
element_combo[frozenset(("cave","space travel"))] = "Did Not Work"
element_combo[frozenset(("cave","spacetime"))] = "Did Not Work"
element_combo[frozenset(("cave","star"))] = "Did Not Work"
element_combo[frozenset(("cave","supernova"))] = "Did Not Work"
element_combo[frozenset(("cave","cracking station"))] = "Did Not Work"
element_combo[frozenset(("cave","hatching station"))] = "Did Not Work"
element_combo[frozenset(("cracking station","earth"))] = "Did Not Work"
element_combo[frozenset(("energy","cracking station"))] = "Did Not Work"
element_combo[frozenset(("erosion","cracking station"))] = "Did Not Work"
element_combo[frozenset(("fusion","cracking station"))] = "Did Not Work"
element_combo[frozenset(("gravity","cracking station"))] = "Did Not Work"
element_combo[frozenset(("hatching station","cracking station"))] = "Did Not Work"
element_combo[frozenset(("cracking station","human"))] = "Did Not Work"
element_combo[frozenset(("cracking station","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("mass","cracking station"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","cracking station"))] = "Did Not Work"
element_combo[frozenset(("cracking station","nebula"))] = "Did Not Work"
element_combo[frozenset(("neutron star","cracking station"))] = "Did Not Work"
element_combo[frozenset(("cracking station","planet"))] = "Did Not Work"
element_combo[frozenset(("cracking station","space"))] = "Did Not Work"
element_combo[frozenset(("cracking station","space travel"))] = "Did Not Work"
element_combo[frozenset(("spacetime","cracking station"))] = "Did Not Work"
element_combo[frozenset(("cracking station","star"))] = "Did Not Work"
element_combo[frozenset(("cracking station","supernova"))] = "Did Not Work"
element_combo[frozenset(("cracking station","time"))] = "Did Not Work"
element_combo[frozenset(("cave","egg"))] = "Did Not Work"
element_combo[frozenset(("cracking station","egg"))] = "Did Not Work"
element_combo[frozenset(("egg","earth"))] = "Did Not Work"
element_combo[frozenset(("energy","earth"))] = "Did Not Work"
element_combo[frozenset(("erosion","earth"))] = "Did Not Work"
element_combo[frozenset(("fusion","earth"))] = "Did Not Work"
element_combo[frozenset(("gravity","earth"))] = "Did Not Work"
element_combo[frozenset(("hatching station","earth"))] = "Did Not Work"
element_combo[frozenset(("human","earth"))] = "Did Not Work"
element_combo[frozenset(("hydrogen","earth"))] = "Did Not Work"
element_combo[frozenset(("mass","earth"))] = "Did Not Work"
element_combo[frozenset(("meteor","earth"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","earth"))] = "Did Not Work"
element_combo[frozenset(("nebula","earth"))] = "Did Not Work"
element_combo[frozenset(("neutron star","earth"))] = "Did Not Work"
element_combo[frozenset(("planet","earth"))] = "Did Not Work"
element_combo[frozenset(("space","earth"))] = "Did Not Work"
element_combo[frozenset(("space travel","earth"))] = "Did Not Work"
element_combo[frozenset(("spacetime","earth"))] = "Did Not Work"
element_combo[frozenset(("star","earth"))] = "Did Not Work"
element_combo[frozenset(("supernova","earth"))] = "Did Not Work"
element_combo[frozenset(("time","earth"))] = "Did Not Work"
element_combo[frozenset(("energy","egg"))] = "Did Not Work"
element_combo[frozenset(("erosion","egg"))] = "Did Not Work"
element_combo[frozenset(("fusion","egg"))] = "Did Not Work"
element_combo[frozenset(("gravity","egg"))] = "Did Not Work"
element_combo[frozenset(("hatching station","egg"))] = "Did Not Work"
element_combo[frozenset(("egg","human"))] = "Did Not Work"
element_combo[frozenset(("egg","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("mass","egg"))] = "Did Not Work"
element_combo[frozenset(("egg","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","egg"))] = "Did Not Work"
element_combo[frozenset(("egg","nebula"))] = "Did Not Work"
element_combo[frozenset(("neutron star","egg"))] = "Did Not Work"
element_combo[frozenset(("egg","planet"))] = "Did Not Work"
element_combo[frozenset(("egg","space"))] = "Did Not Work"
element_combo[frozenset(("egg","space travel"))] = "Did Not Work"
element_combo[frozenset(("spacetime","egg"))] = "Did Not Work"
element_combo[frozenset(("egg","star"))] = "Did Not Work"
element_combo[frozenset(("egg","supernova"))] = "Did Not Work"
element_combo[frozenset(("egg","time"))] = "Did Not Work"
element_combo[frozenset(("hatching station","energy"))] = "Did Not Work"
element_combo[frozenset(("energy","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","energy"))] = "Did Not Work"
element_combo[frozenset(("energy","space travel"))] = "Did Not Work"
element_combo[frozenset(("hatching station","erosion"))] = "Did Not Work"
element_combo[frozenset(("erosion","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","erosion"))] = "Did Not Work"
element_combo[frozenset(("erosion","space travel"))] = "Did Not Work"
element_combo[frozenset(("hatching station","fusion"))] = "Did Not Work"
element_combo[frozenset(("fusion","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","fusion"))] = "Did Not Work"
element_combo[frozenset(("fusion","space travel"))] = "Did Not Work"
element_combo[frozenset(("hatching station","gravity"))] = "Did Not Work"
element_combo[frozenset(("gravity","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","gravity"))] = "Did Not Work"
element_combo[frozenset(("gravity","space travel"))] = "Did Not Work"
element_combo[frozenset(("hatching station","human"))] = "Did Not Work"
element_combo[frozenset(("hatching station","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("hatching station","mass"))] = "Did Not Work"
element_combo[frozenset(("hatching station","meteor"))] = "Did Not Work"
element_combo[frozenset(("hatching station","meteor shower"))] = "Did Not Work"
element_combo[frozenset(("hatching station","nebula"))] = "Did Not Work"
element_combo[frozenset(("hatching station","neutron star"))] = "Did Not Work"
element_combo[frozenset(("hatching station","planet"))] = "Did Not Work"
element_combo[frozenset(("hatching station","space"))] = "Did Not Work"
element_combo[frozenset(("hatching station","space travel"))] = "Did Not Work"
element_combo[frozenset(("hatching station","spacetime"))] = "Did Not Work"
element_combo[frozenset(("hatching station","star"))] = "Did Not Work"
element_combo[frozenset(("hatching station","supernova"))] = "Did Not Work"
element_combo[frozenset(("hatching station","time"))] = "Did Not Work"
element_combo[frozenset(("meteor","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("space travel","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("mass","meteor"))] = "Did Not Work"
element_combo[frozenset(("mass","meteor shower"))] = "Did Not Work"
element_combo[frozenset(("mass","space travel"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","meteor"))] = "Did Not Work"
element_combo[frozenset(("nebula","meteor"))] = "Did Not Work"
element_combo[frozenset(("neutron star","meteor"))] = "Did Not Work"
element_combo[frozenset(("space","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor","space travel"))] = "Did Not Work"
element_combo[frozenset(("spacetime","meteor"))] = "Did Not Work"
element_combo[frozenset(("star","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor","supernova"))] = "Did Not Work"
element_combo[frozenset(("meteor","time"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","nebula"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","neutron star"))] = "Did Not Work"
element_combo[frozenset(("cave","dragon rider"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","cracking station"))] = "Did Not Work"
element_combo[frozenset(("cracking station","dust"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","dust"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","earth"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","egg"))] = "Did Not Work"
element_combo[frozenset(("energy","dragon rider"))] = "Did Not Work"
element_combo[frozenset(("erosion","dragon rider"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","fusion"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","gravity"))] = "Did Not Work"
element_combo[frozenset(("hatching station","dragon rider"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","human"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("mass","dragon rider"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","dragon rider"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","nebula"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","neutron star"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","planet"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","space"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","space travel"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","spacetime"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","star"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","supernova"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","time"))] = "Did Not Work"
element_combo[frozenset(("dust","earth"))] = "Did Not Work"
element_combo[frozenset(("egg","dust"))] = "Did Not Work"
element_combo[frozenset(("cave","nesting station"))] = "Did Not Work"
element_combo[frozenset(("cracking station","nesting station"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","nesting station"))] = "Did Not Work"
element_combo[frozenset(("energy","dust"))] = "Did Not Work"
element_combo[frozenset(("erosion","dust"))] = "Did Not Work"
element_combo[frozenset(("fusion","dust"))] = "Did Not Work"
element_combo[frozenset(("gravity","dust"))] = "Did Not Work"
element_combo[frozenset(("hatching station","dust"))] = "Did Not Work"
element_combo[frozenset(("human","dust"))] = "Did Not Work"
element_combo[frozenset(("dust","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("mass","dust"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","dust"))] = "Did Not Work"
element_combo[frozenset(("nebula","dust"))] = "Did Not Work"
element_combo[frozenset(("dust","nesting station"))] = "Did Not Work"
element_combo[frozenset(("neutron star","dust"))] = "Did Not Work"
element_combo[frozenset(("planet","dust"))] = "Did Not Work"
element_combo[frozenset(("space","dust"))] = "Did Not Work"
element_combo[frozenset(("dust","space travel"))] = "Did Not Work"
element_combo[frozenset(("spacetime","dust"))] = "Did Not Work"
element_combo[frozenset(("star","dust"))] = "Did Not Work"
element_combo[frozenset(("dust","supernova"))] = "Did Not Work"
element_combo[frozenset(("dust","time"))] = "Did Not Work"
element_combo[frozenset(("cave","metal dust"))] = "Did Not Work"
element_combo[frozenset(("metal dust","cracking station"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","metal dust"))] = "Did Not Work"
element_combo[frozenset(("metal dust","dust"))] = "Did Not Work"
element_combo[frozenset(("metal dust","earth"))] = "Did Not Work"
element_combo[frozenset(("nesting station","earth"))] = "Did Not Work"
element_combo[frozenset(("metal dust","egg"))] = "Did Not Work"
element_combo[frozenset(("energy","metal dust"))] = "Did Not Work"
element_combo[frozenset(("energy","nesting station"))] = "Did Not Work"
element_combo[frozenset(("erosion","metal dust"))] = "Did Not Work"
element_combo[frozenset(("erosion","nesting station"))] = "Did Not Work"
element_combo[frozenset(("metal dust","fusion"))] = "Did Not Work"
element_combo[frozenset(("fusion","nesting station"))] = "Did Not Work"
element_combo[frozenset(("gravity","metal dust"))] = "Did Not Work"
element_combo[frozenset(("gravity","nesting station"))] = "Did Not Work"
element_combo[frozenset(("hatching station","metal dust"))] = "Did Not Work"
element_combo[frozenset(("hatching station","nesting station"))] = "Did Not Work"
element_combo[frozenset(("metal dust","human"))] = "Did Not Work"
element_combo[frozenset(("human","nesting station"))] = "Did Not Work"
element_combo[frozenset(("metal dust","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("nesting station","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("mass","metal dust"))] = "Did Not Work"
element_combo[frozenset(("mass","nesting station"))] = "Did Not Work"
element_combo[frozenset(("metal dust","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","metal dust"))] = "Did Not Work"
element_combo[frozenset(("metal dust","nebula"))] = "Did Not Work"
element_combo[frozenset(("metal dust","nested egg"))] = "Did Not Work"
element_combo[frozenset(("metal dust","nesting station"))] = "Did Not Work"
element_combo[frozenset(("neutron star","metal dust"))] = "Did Not Work"
element_combo[frozenset(("metal dust","planet"))] = "Did Not Work"
element_combo[frozenset(("metal dust","space"))] = "Did Not Work"
element_combo[frozenset(("metal dust","space travel"))] = "Did Not Work"
element_combo[frozenset(("spacetime","metal dust"))] = "Did Not Work"
element_combo[frozenset(("metal dust","star"))] = "Did Not Work"
element_combo[frozenset(("metal dust","supernova"))] = "Did Not Work"
element_combo[frozenset(("metal dust","time"))] = "Did Not Work"
element_combo[frozenset(("cave","nested egg"))] = "Did Not Work"
element_combo[frozenset(("nested egg","cracking station"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","nested egg"))] = "Did Not Work"
element_combo[frozenset(("nested egg","dust"))] = "Did Not Work"
element_combo[frozenset(("nested egg","earth"))] = "Did Not Work"
element_combo[frozenset(("nested egg","egg"))] = "Did Not Work"
element_combo[frozenset(("energy","nested egg"))] = "Did Not Work"
element_combo[frozenset(("erosion","nested egg"))] = "Did Not Work"
element_combo[frozenset(("nested egg","fusion"))] = "Did Not Work"
element_combo[frozenset(("gravity","nested egg"))] = "Did Not Work"
element_combo[frozenset(("nested egg","human"))] = "Did Not Work"
element_combo[frozenset(("nested egg","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("mass","nested egg"))] = "Did Not Work"
element_combo[frozenset(("nested egg","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor","nesting station"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","nested egg"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","nesting station"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","space"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","space travel"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","spacetime"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","star"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","supernova"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","time"))] = "Did Not Work"
element_combo[frozenset(("cave","baby dragon"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","cracking station"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","dragon rider"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","dust"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","earth"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","egg"))] = "Did Not Work"
element_combo[frozenset(("energy","baby dragon"))] = "Did Not Work"
element_combo[frozenset(("erosion","baby dragon"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","fusion"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","gravity"))] = "Did Not Work"
element_combo[frozenset(("hatching station","baby dragon"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","human"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("mass","baby dragon"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","metal dust"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","baby dragon"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","nebula"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","nested egg"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","nesting station"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","neutron star"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","planet"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","space"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","space travel"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","spacetime"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","star"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","supernova"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","dragon"))] = "Did Not Work"
element_combo[frozenset(("cave","dragon"))] = "Did Not Work"
element_combo[frozenset(("cracking station","dragon"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","dragon"))] = "Did not work"
element_combo[frozenset(("dust","dragon"))] = "Did Not Work"
element_combo[frozenset(("earth","dragon"))] = "Did Not Work"
element_combo[frozenset(("egg","dragon"))] = "Did Not Work"
element_combo[frozenset(("energy","dragon"))] = "Did Not Work"
element_combo[frozenset(("erosion","dragon"))] = "Did Not Work"
element_combo[frozenset(("fusion","dragon"))] = "Did Not Work"
element_combo[frozenset(("gravity","dragon"))] = "Did Not Work"
element_combo[frozenset(("hatching station","dragon"))] = "Did Not Work"
element_combo[frozenset(("human","dragon"))] = "Did Not Work"
element_combo[frozenset(("hydrogen","dragon"))] = "Did Not Work"
element_combo[frozenset(("mass","dragon"))] = "Did Not Work"
element_combo[frozenset(("metal dust","dragon"))] = "Did Not Work"
element_combo[frozenset(("meteor","dragon"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","dragon"))] = "Did Not Work"
element_combo[frozenset(("nebula","dragon"))] = "Did Not Work"
element_combo[frozenset(("nested egg","dragon"))] = "Did Not Work"
element_combo[frozenset(("nesting station","dragon"))] = "Did Not Work"
element_combo[frozenset(("neutron star","dragon"))] = "Did Not Work"
element_combo[frozenset(("planet","dragon"))] = "Did Not Work"
element_combo[frozenset(("space","dragon"))] = "Did Not Work"
element_combo[frozenset(("space travel","dragon"))] = "Did Not Work"
element_combo[frozenset(("spacetime","dragon"))] = "Did Not Work"
element_combo[frozenset(("star","dragon"))] = "Did Not Work"
element_combo[frozenset(("supernova","dragon"))] = "Did Not Work"
element_combo[frozenset(("time","dragon"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","baby dragon"))] = "Did Not Work"
element_combo[frozenset(("cave","dragonfire"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","cracking station"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","dragon rider"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","dust"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","earth"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","egg"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","energy"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","erosion"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","fusion"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","gravity"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","hatching station"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","human"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","mass"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","metal dust"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","meteor"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","meteor shower"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","nebula"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","nested egg"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","nesting station"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","neutron star"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","planet"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","space"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","space travel"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","spacetime"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","star"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","supernova"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","time"))] = "Did Not Work"
element_combo[frozenset(("nested egg","nebula"))] = "Did Not Work"
element_combo[frozenset(("nebula","nesting station"))] = "Did Not Work"
element_combo[frozenset(("nebula","space travel"))] = "Did Not Work"
element_combo[frozenset(("nested egg","nesting station"))] = "Did Not Work"
element_combo[frozenset(("neutron star","nested egg"))] = "Did Not Work"
element_combo[frozenset(("nested egg","planet"))] = "Did Not Work"
element_combo[frozenset(("nested egg","space"))] = "Did Not Work"
element_combo[frozenset(("nested egg","space travel"))] = "Did Not Work"
element_combo[frozenset(("spacetime","nested egg"))] = "Did Not Work"
element_combo[frozenset(("nested egg","star"))] = "Did Not Work"
element_combo[frozenset(("nested egg","supernova"))] = "Did Not Work"
element_combo[frozenset(("nested egg","time"))] = "Did Not Work"
element_combo[frozenset(("neutron star","nesting station"))] = "Did Not Work"
element_combo[frozenset(("planet","nesting station"))] = "Did Not Work"
element_combo[frozenset(("space","nesting station"))] = "Did Not Work"
element_combo[frozenset(("space travel","nesting station"))] = "Did Not Work"
element_combo[frozenset(("spacetime","nesting station"))] = "Did Not Work"
element_combo[frozenset(("star","nesting station"))] = "Did Not Work"
element_combo[frozenset(("supernova","nesting station"))] = "Did Not Work"
element_combo[frozenset(("time","nesting station"))] = "Did Not Work"
element_combo[frozenset(("neutron star","space travel"))] = "Did Not Work"
element_combo[frozenset(("space","space travel"))] = "Did Not Work"
element_combo[frozenset(("spacetime","space travel"))] = "Did Not Work"
element_combo[frozenset(("star","space travel"))] = "Did Not Work"
element_combo[frozenset(("supernova","space travel"))] = "Did Not Work"
element_combo[frozenset(("time","space travel"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","mars"))] = "Did Not Work"
element_combo[frozenset(("cave","mars"))] = "Did Not Work"
element_combo[frozenset(("cracking station","mars"))] = "Did Not Work"
element_combo[frozenset(("mars","dragon"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","mars"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","mars"))] = "Did Not Work"
element_combo[frozenset(("mars","dust"))] = "Did Not Work"
element_combo[frozenset(("mars","earth"))] = "Did Not Work"
element_combo[frozenset(("egg","mars"))] = "Did Not Work"
element_combo[frozenset(("energy","mars"))] = "Did Not Work"
element_combo[frozenset(("fusion","mars"))] = "Did Not Work"
element_combo[frozenset(("gravity","mars"))] = "Did Not Work"
element_combo[frozenset(("hatching station","mars"))] = "Did Not Work"
element_combo[frozenset(("human","mars"))] = "Did Not Work"
element_combo[frozenset(("mars","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("mass","mars"))] = "Did Not Work"
element_combo[frozenset(("martian sand","mars"))] = "Did Not Work"
element_combo[frozenset(("martian metal","mars"))] = "Did not work"
element_combo[frozenset(("mars","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","mars"))] = "Did Not Work"
element_combo[frozenset(("nebula","mars"))] = "Did Not Work"
element_combo[frozenset(("nested egg","mars"))] = "Did Not Work"
element_combo[frozenset(("mars","nesting station"))] = "Did Not Work"
element_combo[frozenset(("neutron star","mars"))] = "Did Not Work"
element_combo[frozenset(("planet","mars"))] = "Did Not Work"
element_combo[frozenset(("mars","space"))] = "Did Not Work"
element_combo[frozenset(("mars","space travel"))] = "Did Not Work"
element_combo[frozenset(("spacetime","mars"))] = "Did Not Work"
element_combo[frozenset(("mars","star"))] = "Did Not Work"
element_combo[frozenset(("mars","supernova"))] = "Did Not Work"
element_combo[frozenset(("mars","time"))] = "Did Not Work"
element_combo[frozenset(("martian metal","baby dragon"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","martian sand"))] = "Did Not Work"
element_combo[frozenset(("cave","martian metal"))] = "Did Not Work"
element_combo[frozenset(("cave","martian sand"))] = "Did Not Work"
element_combo[frozenset(("martian metal","cracking station"))] = "Did Not Work"
element_combo[frozenset(("cracking station","martian sand"))] = "Did Not Work"
element_combo[frozenset(("martian metal","dragon"))] = "Did Not Work"
element_combo[frozenset(("martian sand","dragon"))] = "Did Not Work"
element_combo[frozenset(("martian metal","dragon rider"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","martian sand"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","martian metal"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","martian sand"))] = "Did Not Work"
element_combo[frozenset(("martian metal","dust"))] = "Did Not Work"
element_combo[frozenset(("martian sand","dust"))] = "Did Not Work"
element_combo[frozenset(("martian metal","earth"))] = "Did Not Work"
element_combo[frozenset(("martian sand","earth"))] = "Did Not Work"
element_combo[frozenset(("martian metal","egg"))] = "Did Not Work"
element_combo[frozenset(("egg","martian sand"))] = "Did Not Work"
element_combo[frozenset(("martian metal","energy"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","thermal bricks"))] = "Did Not Work"
element_combo[frozenset(("cave","thermal bricks"))] = "Did Not Work"
element_combo[frozenset(("thermal bricks","cracking station"))] = "Did Not Work"
element_combo[frozenset(("thermal bricks","dragon"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","thermal bricks"))] = "Did Not Work"
element_combo[frozenset(("thermal bricks","forge"))] = "Did Not Work"
element_combo[frozenset(("thermal bricks","dust"))] = "Did Not Work"
element_combo[frozenset(("thermal bricks","earth"))] = "Did Not Work"
element_combo[frozenset(("thermal bricks","egg"))] = "Did Not Work"
element_combo[frozenset(("energy","thermal bricks"))] = "Did Not Work"
element_combo[frozenset(("martian metal","erosion"))] = "Did Not Work"
element_combo[frozenset(("erosion","martian sand"))] = "Did Not Work"
element_combo[frozenset(("erosion","thermal bricks"))] = "Did Not Work"
element_combo[frozenset(("martian metal","fusion"))] = "Did Not Work"
element_combo[frozenset(("fusion","martian sand"))] = "Did Not Work"
element_combo[frozenset(("martian metal","gravity"))] = "Did Not Work"
element_combo[frozenset(("gravity","martian sand"))] = "Did Not Work"
element_combo[frozenset(("gravity","thermal bricks"))] = "Did Not Work"
element_combo[frozenset(("hatching station","martian metal"))] = "Did Not Work"
element_combo[frozenset(("hatching station","martian sand"))] = "Did Not Work"
element_combo[frozenset(("hatching station","thermal bricks"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("baby dragon","forge"))] = "Did Not Work"
element_combo[frozenset(("cave","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("cave","forge"))] = "Did Not Work"
element_combo[frozenset(("cracking station","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("forge","cracking station"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","dragon"))] = "Did Not Work"
element_combo[frozenset(("forge","dragon"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","forge"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","forge"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","dust"))] = "Did Not Work"
element_combo[frozenset(("forge","dust"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","earth"))] = "Did Not Work"
element_combo[frozenset(("forge","earth"))] = "Did Not Work"
element_combo[frozenset(("egg","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("forge","egg"))] = "Did Not Work"
element_combo[frozenset(("energy","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("energy","forge"))] = "Did Not Work"
element_combo[frozenset(("erosion","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("erosion","forge"))] = "Did Not Work"
element_combo[frozenset(("forge","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("fusion","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("gravity","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("hatching station","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","human"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","mars"))] = "Did Not Work"
element_combo[frozenset(("martian metal","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","martian sand"))] = "Did Not Work"
element_combo[frozenset(("mass","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("metal dust","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","nebula"))] = "Did Not Work"
element_combo[frozenset(("nested egg","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","nesting station"))] = "Did Not Work"
element_combo[frozenset(("neutron star","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","planet"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","space"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","space travel"))] = "Did Not Work"
element_combo[frozenset(("spacetime","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","star"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","supernova"))] = "Did Not Work"
element_combo[frozenset(("thermal bricks","fire cladding"))] = "Did Not Work"
element_combo[frozenset(("fire cladding","time"))] = "Did Not Work"
element_combo[frozenset(("fusion","forge"))] = "Did Not Work"
element_combo[frozenset(("gravity","forge"))] = "Did Not Work"
element_combo[frozenset(("hatching station","forge"))] = "Did Not Work"
element_combo[frozenset(("forge","human"))] = "Did Not Work"
element_combo[frozenset(("forge","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("forge","mars"))] = "Did Not Work"
element_combo[frozenset(("martian metal","forge"))] = "Did Not Work"
element_combo[frozenset(("forge","martian sand"))] = "Did Not Work"
element_combo[frozenset(("mass","forge"))] = "Did Not Work"
element_combo[frozenset(("metal dust","forge"))] = "Did Not Work"
element_combo[frozenset(("forge","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","forge"))] = "Did Not Work"
element_combo[frozenset(("forge","nebula"))] = "Did Not Work"
element_combo[frozenset(("nested egg","forge"))] = "Did Not Work"
element_combo[frozenset(("forge","nesting station"))] = "Did Not Work"
element_combo[frozenset(("neutron star","forge"))] = "Did Not Work"
element_combo[frozenset(("forge","planet"))] = "Did Not Work"
element_combo[frozenset(("forge","space"))] = "Did Not Work"
element_combo[frozenset(("forge","space travel"))] = "Did Not Work"
element_combo[frozenset(("spacetime","forge"))] = "Did Not Work"
element_combo[frozenset(("forge","star"))] = "Did Not Work"
element_combo[frozenset(("forge","supernova"))] = "Did Not Work"
element_combo[frozenset(("forge","time"))] = "Did Not Work"
element_combo[frozenset(("martian metal","human"))] = "Did Not Work"
element_combo[frozenset(("human","martian sand"))] = "Did Not Work"
element_combo[frozenset(("thermal bricks","human"))] = "Did Not Work"
element_combo[frozenset(("martian metal","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("martian sand","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("thermal bricks","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("thermal bricks","mars"))] = "Did Not Work"
element_combo[frozenset(("martian metal","martian sand"))] = "Did Not Work"
element_combo[frozenset(("mass","martian metal"))] = "Did Not Work"
element_combo[frozenset(("martian metal","metal dust"))] = "Did Not Work"
element_combo[frozenset(("martian metal","meteor"))] = "Did Not Work"
element_combo[frozenset(("meteor shower","martian metal"))] = "Did Not Work"
element_combo[frozenset(("martian metal","nebula"))] = "Did Not Work"
element_combo[frozenset(("martian metal","nested egg"))] = "Did Not Work"
element_combo[frozenset(("martian metal","nesting station"))] = "Did Not Work"
element_combo[frozenset(("martian metal","neutron star"))] = "Did Not Work"
element_combo[frozenset(("martian metal","planet"))] = "Did Not Work"
element_combo[frozenset(("martian metal","space"))] = "Did Not Work"
element_combo[frozenset(("martian metal","space travel"))] = "Did Not Work"
element_combo[frozenset(("martian metal","spacetime"))] = "Did Not Work"
element_combo[frozenset(("martian metal","star"))] = "Did Not Work"
element_combo[frozenset(("martian metal","supernova"))] = "Did Not Work"
element_combo[frozenset(("martian metal","time"))] = "Did Not Work"




element_combo[frozenset(("baby dragon","structure"))] = "Did Not Work"
element_combo[frozenset(("cave","structure"))] = "Did Not Work"
element_combo[frozenset(("structure","cracking station"))] = "Did Not Work"
element_combo[frozenset(("structure","dragon"))] = "Did Not Work"
element_combo[frozenset(("dragon rider","structure"))] = "Did Not Work"
element_combo[frozenset(("dragonfire","structure"))] = "Did Not Work"
element_combo[frozenset(("structure","dust"))] = "Did Not Work"
element_combo[frozenset(("structure","earth"))] = "Did Not Work"
element_combo[frozenset(("structure","egg"))] = "Did Not Work"
element_combo[frozenset(("energy","structure"))] = "Did Not Work"
element_combo[frozenset(("erosion","structure"))] = "Did Not Work"



element_combo[frozenset(("structure","forge"))] = "Did Not Work"
element_combo[frozenset(("structure","fusion"))] = "Did Not Work"
element_combo[frozenset(("gravity","structure"))] = "Did Not Work"
element_combo[frozenset(("hatching station","structure"))] = "Did Not Work"



element_combo[frozenset(("structure","hydrogen"))] = "Did Not Work"
element_combo[frozenset(("structure","mars"))] = "Did Not Work"
element_combo[frozenset(("martian metal","structure"))] = "Did Not Work"

# %%
for i,j in dict(sorted(element_combo.items(),key=lambda item: item[1])).items():
    if j=="":
#         a = i[0][0]
#         b = i[0][1]
        a,b = tuple(i)
        print(f'element_combo[frozenset(("{a}","{b}"))] = "Did Not Work"')
# Out:
# element_combo[frozenset(("baby dragon","structure"))] = "Did Not Work"
# element_combo[frozenset(("cave","structure"))] = "Did Not Work"
# element_combo[frozenset(("structure","cracking station"))] = "Did Not Work"
# element_combo[frozenset(("structure","dragon"))] = "Did Not Work"
# element_combo[frozenset(("dragon rider","structure"))] = "Did Not Work"
# element_combo[frozenset(("dragonfire","structure"))] = "Did Not Work"
# element_combo[frozenset(("structure","dust"))] = "Did Not Work"
# element_combo[frozenset(("structure","earth"))] = "Did Not Work"
# element_combo[frozenset(("structure","egg"))] = "Did Not Work"
# element_combo[frozenset(("energy","structure"))] = "Did Not Work"
# element_combo[frozenset(("erosion","structure"))] = "Did Not Work"
# element_combo[frozenset(("structure","fire cladding"))] = "Did Not Work"
# element_combo[frozenset(("structure","forge"))] = "Did Not Work"
# element_combo[frozenset(("structure","fusion"))] = "Did Not Work"
# ...

# %%
dict(sorted(element_combo.items(),key=lambda item: item[1]))
# Out:
# {frozenset({'cave', 'egg'}): '',
#  frozenset({'cracking station', 'egg'}): '',
#  frozenset({'earth', 'egg'}): '',
#  frozenset({'earth', 'energy'}): '',
#  frozenset({'earth', 'erosion'}): '',
#  frozenset({'earth', 'fusion'}): '',
#  frozenset({'earth', 'gravity'}): '',
#  frozenset({'earth', 'hatching station'}): '',
#  frozenset({'earth', 'human'}): '',
#  frozenset({'earth', 'hydrogen'}): '',
#  frozenset({'earth', 'mass'}): '',
#  frozenset({'earth', 'meteor'}): '',
#  frozenset({'earth', 'meteor shower'}): '',
#  frozenset({'earth', 'nebula'}): '',
#  frozenset({'earth', 'neutron star'}): '',
#  frozenset({'earth', 'planet'}): '',
#  frozenset({'earth', 'space'}): '',
#  frozenset({'earth', 'space travel'}): '',
#  frozenset({'earth', 'spacetime'}): '',
#  frozenset({'earth', 'star'}): '',
#  frozenset({'earth', 'supernova'}): '',
#  frozenset({'earth', 'time'}): '',
#  frozenset({'egg', 'energy'}): '',
#  frozenset({'egg', 'erosion'}): '',
# ...
